# %% [markdown]
# #### part1
#
# #### Automatically generated by Colaboratory.
#
# #### Original file is located at
# ####     https://colab.research.google.com/drive/1ZP4YpBp15Al7iq5KrzbsbAlPFBYxKndb
#
# #### #Assignment 1: Part 1 - Linear Regression Using Gradient Descent
# #### #Submitted by:
#
# #### - Train a linear model on a dataset
# ####   - Implement the model from scratch using the numpy and pandas libraries (linearRegression class)
# ####   - Pre-Process the dataset (Dataset used - https://archive.ics.uci.edu/ml/datasets/Real+estate+valuation+data+set#)
# ####   - Use learning curve and other plots to understand more about the linear model
# ####   - Tune parameters such as learning rate, no of iterations etc. to achieve the optimum error value
# ####   - Measure the model using various evaluation statistics - MSE, ASE, R2 value, explained variance.
#
# #### We will use the following packages:
